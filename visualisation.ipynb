# %%
import pandas as pd
from main import preprocess_df


df = pd.read_csv(
    "./datasets/lc_data_2007_to_2018.csv",
    low_memory=False,
    encoding="latin1",
    nrows=100000,  # only looking at 100k rows right now for performance
)
pd.set_option("display.max_columns", None)
cleaned_df = preprocess_df(df)

# %%
print(cleaned_df.head())
# Out:
#    loan_amnt term  int_rate  installment grade  annual_inc    dti  \
# 0     3600.0   36     13.99       123.03     2     55000.0   5.91
# 1    24700.0   36     11.99       820.28     2     65000.0  16.06
# 2    20000.0   60     10.78       432.66     1     63000.0  10.78
# 4    10400.0   60     22.45       289.91     5    104433.0  25.37
# 5    11950.0   36     13.44       405.18     2     34000.0  10.20
#
#   verification_status  total_acc  open_acc  delinq_2yrs  inq_last_6mths  \
# 0                   0       13.0       7.0          0.0             1.0
# 1                   0       38.0      22.0          1.0             4.0
# 2                   0       18.0       6.0          0.0             0.0
# 4                   2       35.0      12.0          1.0             3.0
# 5                   2        6.0       5.0          0.0             0.0
#
#    pub_rec  revol_util  revol_bal home_ownership  did_default  avg_fico  \
# 0      0.0        29.7     2765.0            1.0        False     677.0
# 1      0.0        19.2    21470.0            1.0        False     717.0
# 2      0.0        56.2     7869.0            1.0        False     697.0
# 4      0.0        64.5    21929.0            1.0        False     697.0
# 5      0.0        68.4     8822.0            0.0        False     692.0
#
#    credit_age_yrs
# 0           12.33
# 1           16.00
# 2           15.33
# 4           17.50
# 5           28.17

# %%
print(min(cleaned_df["avg_fico"]))
print(max(cleaned_df["avg_fico"]))
# Out:
# 662.0
# 847.5
