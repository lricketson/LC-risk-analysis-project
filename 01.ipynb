# %%
import numpy as np
import pandas as pd

PERCENTAGE_CONSTANT = 100
NAN_CUTOFF = 0.95

df = pd.read_csv(
    "./datasets/lc_data_2007_to_2018.csv",
    low_memory=False,
    encoding="latin1",
    nrows=10000,  # only looking at 10k rows right now for performance
)
pd.set_option("display.max_columns", None)

# %%
for col in df.columns:
  print(col)

# %%
from main import preprocess_20col_version
cleaned_df = preprocess_20col_version(df)
print(len(cleaned_df.columns))
print(cleaned_df.columns)
print(cleaned_df.head())

# %%
print(min(cleaned_df["credit_age_yrs"]))
