# %%
import numpy as np
import pandas as pd

PERCENTAGE_CONSTANT = 100
NAN_CUTOFF = 0.95

df = pd.read_csv(
    "./datasets/lc_data_2007_to_2018.csv",
    low_memory=False,
    encoding="latin1",
    nrows=10000,  # only looking at 10k rows right now for performance
)
pd.set_option("display.max_columns", None)

# %%
for col in df.columns:
  print(col)

# %%
from main import clean_lc_df

cleaned_df = clean_lc_df(df)
for col in cleaned_df.columns:
  print(col)

# %%
from main import preprocess_20col_version
kept_df = preprocess_20col_version(df)
print(len(kept_df.columns))
print(kept_df.columns)
print(kept_df.head())
# Out:
# 19
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade',
#        'home_ownership', 'annual_inc', 'verification_status', 'dti',
#        'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'avg_fico',
#        'did_default'],
#       dtype='object')
#    loan_amnt        term  int_rate  installment grade home_ownership  \
# 0     3600.0   36 months     13.99       123.03     C       MORTGAGE
# 1    24700.0   36 months     11.99       820.28     C       MORTGAGE
# 2    20000.0   60 months     10.78       432.66     B       MORTGAGE
# 4    10400.0   60 months     22.45       289.91     F       MORTGAGE
# 5    11950.0   36 months     13.44       405.18     C           RENT
#
#    annual_inc verification_status    dti  delinq_2yrs earliest_cr_line  \
# 0     55000.0        Not Verified   5.91          0.0         Aug-2003
# 1     65000.0        Not Verified  16.06          1.0         Dec-1999
# ...
